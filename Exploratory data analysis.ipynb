# %% [markdown]
# # Exploratory Data Analysis
# ### Vishesh Batta

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from numpy.ma.core import count

# %%
heart= pd.read_csv("C:/Users/vish_/Downloads/Heart Failure Prediction Dataset.csv")
heart
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
heart['Sex']=heart['Sex'].replace(['M', 'F'] ,[0,1])

# %%
heart['RestingECG']=heart['RestingECG'].replace(['Normal', 'ST','LVH'] ,[0,1,2])

# %%
heart['ChestPainType']=heart['ChestPainType'].replace(['TA','ATA','NAP','ASY'] ,[0,1,2,3])

# %%
heart['ExerciseAngina']=heart['ExerciseAngina'].replace(['N','Y'] ,[0,1])

# %%
heart_new=heart.drop(['Oldpeak', 'ST_Slope'], axis=1)

# %%
heart_new
# Out:
#      Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0     40    0              1        140          289          0           0
# 1     49    1              2        160          180          0           0
# 2     37    0              1        130          283          0           1
# 3     48    1              3        138          214          0           0
# 4     54    0              2        150          195          0           0
# ..   ...  ...            ...        ...          ...        ...         ...
# 913   45    0              0        110          264          0           0
# 914   68    0              3        144          193          1           0
# 915   57    0              3        130          131          0           0
# 916   57    1              1        130          236          0           2
# 917   38    0              2        138          175          0           0
#
#      MaxHR  ExerciseAngina  HeartDisease
# ...

# %%
heart = heart_new

# %%
heart
# Out:
#      Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0     40    0              1        140          289          0           0
# 1     49    1              2        160          180          0           0
# 2     37    0              1        130          283          0           1
# 3     48    1              3        138          214          0           0
# 4     54    0              2        150          195          0           0
# ..   ...  ...            ...        ...          ...        ...         ...
# 913   45    0              0        110          264          0           0
# 914   68    0              3        144          193          1           0
# 915   57    0              3        130          131          0           0
# 916   57    1              1        130          236          0           2
# 917   38    0              2        138          175          0           0
#
#      MaxHR  ExerciseAngina  HeartDisease
# ...

# %%
heart.isnull()
# Out:
#        Age    Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  \
# 0    False  False          False      False        False      False
# 1    False  False          False      False        False      False
# 2    False  False          False      False        False      False
# 3    False  False          False      False        False      False
# 4    False  False          False      False        False      False
# ..     ...    ...            ...        ...          ...        ...
# 913  False  False          False      False        False      False
# 914  False  False          False      False        False      False
# 915  False  False          False      False        False      False
# 916  False  False          False      False        False      False
# 917  False  False          False      False        False      False
#
#      RestingECG  MaxHR  ExerciseAngina  HeartDisease
# 0         False  False           False         False
# ...

# %%
heart.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 913    False
# 914    False
# 915    False
# 916    False
# 917    False
# Length: 918, dtype: bool

# %%
plt.scatter(heart['RestingBP'], heart['Cholesterol'])
plt.xlabel("RestingBP")
plt.ylabel("Cholesterol")
# Out:
# Text(0, 0.5, 'Cholesterol')

# %%
plt.hist(heart['RestingBP'])
plt.title("Histogram of people Resting BP levels")
# Out:
# Text(0.5, 1.0, 'Histogram of people Resting BP levels')

# %%
plt.scatter(heart['Age'], heart['Cholesterol'])
plt.xlabel("Age")
plt.ylabel("Cholesterol")
# Out:
# Text(0, 0.5, 'Cholesterol')

# %%
heart.sort_values(by='RestingBP', ascending=False)
#sorting people with highest to lowest resting BP to see if that correlates with Heart Disease
# Out:
#      Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 241   54    0              3        200          198          0           0
# 399   61    0              2        200            0          1           1
# 732   56    1              3        200          288          1           2
# 365   64    1              3        200            0          0           0
# 759   54    0              1        192          283          0           2
# ..   ...  ...            ...        ...          ...        ...         ...
# 692   39    1              2         94          199          0           0
# 832   51    0              2         94          227          0           0
# 227   38    0              3         92          117          0           0
# 314   53    0              3         80            0          0           0
# 449   55    0              2          0            0          0           0
#
#      MaxHR  ExerciseAngina  HeartDisease
# ...

# %%
heart.plot(kind='box')
plt.show()

# %%
heart.loc[heart['ChestPainType'] == 0]
##Chest pain that contains TA (Typical Angina)
# Out:
#      Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 20    43    1              0        100          223          0           0
# 88    43    0              0        120          291          0           1
# 118   35    1              0        120          160          0           1
# 119   34    0              0        140          156          0           0
# 165   46    0              0        140          272          1           0
# 195   62    1              0        160          193          0           0
# 199   57    1              0        130          308          0           0
# 200   47    0              0        110          249          0           0
# 215   30    1              0        170          237          0           1
# 237   55    0              0        140          295          0           0
# 245   54    0              0        120          171          0           0
# ...

# %%
heart.loc[heart['ChestPainType'] == 1]
#Chest pain that contains ATA (Atypical Angina)
# Out:
#      Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0     40    0              1        140          289          0           0
# 2     37    0              1        130          283          0           1
# 6     45    1              1        130          237          0           0
# 7     54    0              1        110          208          0           0
# 9     48    1              1        120          284          0           0
# ..   ...  ...            ...        ...          ...        ...         ...
# 903   56    0              1        130          221          0           2
# 904   56    0              1        120          240          0           0
# 906   55    1              1        132          342          0           0
# 910   41    0              1        120          157          0           0
# 916   57    1              1        130          236          0           2
#
#      MaxHR  ExerciseAngina  HeartDisease
# ...

# %%
heart.loc[heart['ChestPainType'] == 2]
#Chest pain that contains NAP (Non-Anginal Pain)
# Out:
#      Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 1     49    1              2        160          180          0           0
# 4     54    0              2        150          195          0           0
# 5     39    0              2        120          339          0           0
# 10    37    1              2        130          211          0           0
# 14    42    1              2        115          211          0           1
# ..   ...  ...            ...        ...          ...        ...         ...
# 891   66    1              2        146          278          0           2
# 892   39    1              2        138          220          0           0
# 896   47    0              2        130          253          0           0
# 905   67    0              2        152          212          0           2
# 917   38    0              2        138          175          0           0
#
#      MaxHR  ExerciseAngina  HeartDisease
# ...

# %%
heart.loc[heart['ChestPainType'] == 3]
#Chest pain that contains ASY (Asymptomatic)
# Out:
#      Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 3     48    1              3        138          214          0           0
# 8     37    0              3        140          207          0           0
# 13    49    0              3        140          234          0           0
# 16    38    0              3        110          196          0           0
# 18    60    0              3        100          248          0           0
# ..   ...  ...            ...        ...          ...        ...         ...
# 909   63    1              3        124          197          0           0
# 911   59    0              3        164          176          1           2
# 912   57    1              3        140          241          0           0
# 914   68    0              3        144          193          1           0
# 915   57    0              3        130          131          0           0
#
#      MaxHR  ExerciseAngina  HeartDisease
# ...
